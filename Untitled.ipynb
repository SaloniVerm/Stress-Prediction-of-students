# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("StressLevelDataset.csv")
print(data)
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0                14           20                      0          11         2
# 1                15            8                      1          15         5
# 2                12           18                      1          14         2
# 3                16           12                      1          15         4
# 4                16           28                      0           7         2
# ...             ...          ...                    ...         ...       ...
# 1095             11           17                      0          14         3
# 1096              9           12                      0           8         0
# 1097              4           26                      0           3         1
# 1098             21            0                      1          19         5
# 1099             18            6                      1          15         3
#
# ...

# %%
data.head(5)
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0             14           20                      0          11         2
# 1             15            8                      1          15         5
# 2             12           18                      1          14         2
# 3             16           12                      1          15         4
# 4             16           28                      0           7         2
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0               1              2                  4            2
# 1               3              1                  4            3
# 2               1              2                  2            2
# 3               3              1                  3            4
# 4               3              5                  1            3
#
#    living_conditions  ...  basic_needs  academic_performance  study_load  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   anxiety_level                 1100 non-null   int64
#  1   self_esteem                   1100 non-null   int64
#  2   mental_health_history         1100 non-null   int64
#  3   depression                    1100 non-null   int64
#  4   headache                      1100 non-null   int64
#  5   blood_pressure                1100 non-null   int64
#  6   sleep_quality                 1100 non-null   int64
#  7   breathing_problem             1100 non-null   int64
#  8   noise_level                   1100 non-null   int64
#  9   living_conditions             1100 non-null   int64
#  10  safety                        1100 non-null   int64
#  11  basic_needs                   1100 non-null   int64
#  12  academic_performance          1100 non-null   int64
# ...

# %%
data.tail()
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 1095             11           17                      0          14         3
# 1096              9           12                      0           8         0
# 1097              4           26                      0           3         1
# 1098             21            0                      1          19         5
# 1099             18            6                      1          15         3
#
#       blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 1095               1              3                  2            2
# 1096               3              0                  0            0
# 1097               2              5                  2            2
# 1098               3              1                  4            3
# 1099               3              0                  3            3
#
#       living_conditions  ...  basic_needs  academic_performance  study_load  \
# ...

# %%
data.describe()
# Out:
#        anxiety_level  self_esteem  mental_health_history   depression  \
# count    1100.000000  1100.000000            1100.000000  1100.000000
# mean       11.063636    17.777273               0.492727    12.555455
# std         6.117558     8.944599               0.500175     7.727008
# min         0.000000     0.000000               0.000000     0.000000
# 25%         6.000000    11.000000               0.000000     6.000000
# 50%        11.000000    19.000000               0.000000    12.000000
# 75%        16.000000    26.000000               1.000000    19.000000
# max        21.000000    30.000000               1.000000    27.000000
#
#           headache  blood_pressure  sleep_quality  breathing_problem  \
# count  1100.000000     1100.000000    1100.000000        1100.000000
# mean      2.508182        2.181818       2.660000           2.753636
# std       1.409356        0.833575       1.548383           1.400713
# ...

# %%
data.shape
# Out:
# (1100, 21)

# %%
data.var()
# Out:
# anxiety_level                   37.424518
# self_esteem                     80.005852
# mental_health_history            0.250175
# depression                      59.706658
# headache                         1.986284
# blood_pressure                   0.694847
# sleep_quality                    2.397489
# breathing_problem                1.961998
# noise_level                      1.763921
# living_conditions                1.252626
# safety                           1.977317
# basic_needs                      2.055670
# academic_performance             2.001075
# study_load                       1.731280
# teacher_student_relationship     1.917058
# future_career_concerns           2.338989
# social_support                   1.097940
# peer_pressure                    2.031381
# extracurricular_activities       2.009483
# bullying                         2.343832
# stress_level                     0.675146
# dtype: float64

# %%
corr_matrix=data.corr()
corr_matrix
# Out:
#                               anxiety_level  self_esteem  \
# anxiety_level                      1.000000    -0.672745
# self_esteem                       -0.672745     1.000000
# mental_health_history              0.634450    -0.603502
# depression                         0.694340    -0.699602
# headache                           0.632738    -0.626058
# blood_pressure                     0.330867    -0.514692
# sleep_quality                     -0.710292     0.662693
# breathing_problem                  0.561654    -0.510514
# noise_level                        0.608624    -0.571169
# living_conditions                 -0.568434     0.550535
# safety                            -0.651220     0.643981
# basic_needs                       -0.637079     0.631212
# academic_performance              -0.649601     0.639045
# study_load                         0.586064    -0.575112
# teacher_student_relationship      -0.663176     0.652934
# ...

# %%
data.max()
# Out:
# anxiety_level                   21
# self_esteem                     30
# mental_health_history            1
# depression                      27
# headache                         5
# blood_pressure                   3
# sleep_quality                    5
# breathing_problem                5
# noise_level                      5
# living_conditions                5
# safety                           5
# basic_needs                      5
# academic_performance             5
# study_load                       5
# teacher_student_relationship     5
# future_career_concerns           5
# social_support                   3
# peer_pressure                    5
# extracurricular_activities       5
# bullying                         5
# stress_level                     2
# dtype: int64

# %%
data.dtypes
# Out:
# anxiety_level                   int64
# self_esteem                     int64
# mental_health_history           int64
# depression                      int64
# headache                        int64
# blood_pressure                  int64
# sleep_quality                   int64
# breathing_problem               int64
# noise_level                     int64
# living_conditions               int64
# safety                          int64
# basic_needs                     int64
# academic_performance            int64
# study_load                      int64
# teacher_student_relationship    int64
# future_career_concerns          int64
# social_support                  int64
# peer_pressure                   int64
# extracurricular_activities      int64
# bullying                        int64
# stress_level                    int64
# dtype: object

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1100, step=1)

# %%
data.min()
# Out:
# anxiety_level                   0
# self_esteem                     0
# mental_health_history           0
# depression                      0
# headache                        0
# blood_pressure                  1
# sleep_quality                   0
# breathing_problem               0
# noise_level                     0
# living_conditions               0
# safety                          0
# basic_needs                     0
# academic_performance            0
# study_load                      0
# teacher_student_relationship    0
# future_career_concerns          0
# social_support                  0
# peer_pressure                   0
# extracurricular_activities      0
# bullying                        0
# stress_level                    0
# dtype: int64

# %%
Q1 = data.sleep_quality.quantile(0.25)
Q3 = data.sleep_quality.quantile(0.75)
Q1,Q3
# Out:
# (1.0, 4.0)

# %%
covar=data.cov()
covar
# Out:
#                               anxiety_level  self_esteem  \
# anxiety_level                     37.424518   -36.812019
# self_esteem                      -36.812019    80.005852
# mental_health_history              1.941319    -2.699983
# depression                        32.821764   -48.352970
# headache                           5.455348    -7.892171
# blood_pressure                     1.687236    -3.837538
# sleep_quality                     -6.728116     9.178071
# breathing_problem                  4.812780    -6.396141
# noise_level                        4.945008    -6.785235
# living_conditions                 -3.891968     5.511333
# safety                            -5.602010     8.099756
# basic_needs                       -5.587890     8.094921
# academic_performance              -5.621557     8.085822
# study_load                         4.717446    -6.768566
# teacher_student_relationship      -5.617264     8.086264
# ...

# %%
IQR=Q3-Q1
IQR
# Out:
# 3.0

# %%
lower_limit = Q1-1.5*IQR
upper_limit = Q3+1.5*IQR
lower_limit,upper_limit
# Out:
# (-3.5, 8.5)

# %%
data['mental_health_history'].describe()
# Out:
# count    1100.000000
# mean        0.492727
# std         0.500175
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: mental_health_history, dtype: float64

# %%
data[['anxiety_level','self_esteem','depression']].describe()
# Out:
#        anxiety_level  self_esteem   depression
# count    1100.000000  1100.000000  1100.000000
# mean       11.063636    17.777273    12.555455
# std         6.117558     8.944599     7.727008
# min         0.000000     0.000000     0.000000
# 25%         6.000000    11.000000     6.000000
# 50%        11.000000    19.000000    12.000000
# 75%        16.000000    26.000000    19.000000
# max        21.000000    30.000000    27.000000

# %%
data['stress_level'].value_counts()
# Out:
# 0    373
# 2    369
# 1    358
# Name: stress_level, dtype: int64

# %%
data['blood_pressure'].value_counts()
# Out:
# 3    500
# 1    300
# 2    300
# Name: blood_pressure, dtype: int64

# %% [markdown]
# ##  Descriptive Statistics
# * **1) How many students are in the dataset?**
#
# As noted earlier with the df.index line, there are 1000 students.
#
# * **2) What is the average anxiety level of students in the dataset?**

# %%
data['anxiety_level'].describe()
# Out:
# count    1100.000000
# mean       11.063636
# std         6.117558
# min         0.000000
# 25%         6.000000
# 50%        11.000000
# 75%        16.000000
# max        21.000000
# Name: anxiety_level, dtype: float64

# %% [markdown]
# #### The average anxiety level is 11.06. It is measured from 0 to 21, so it is higher than the scale's mean.
#
# * **3) How many students have reported a history of mental health issues?**

# %%
mental_health_count = data['mental_health_history'].value_counts()
mental_health_count
# Out:
# 0    558
# 1    542
# Name: mental_health_history, dtype: int64

# %%
plt.figure()
sns.barplot(x=mental_health_count.index.map({0: 'No', 1: 'Yes'}), y = mental_health_count.values, palette = 'Set1')
plt.title('Distribution of mental health history')
plt.xlabel('')
plt.ylabel('Number of Students')
plt.show()

# %% [markdown]
# 542 students have reported a mental health issue. Slightly less than 50% of the population.
#
# ## Psychological  Factors
#
# * **1) How many students have a self-esteem level below the average?**

# %%
# Visually:
plt.figure(figsize=(8, 6))
sns.histplot(data['self_esteem'], bins=20, kde=True, color='skyblue')
plt.axvline(data['self_esteem'].mean(), color='red', linestyle='dashed', linewidth=2, label=f'Average: {data["self_esteem"].mean():.2f}')
plt.title('Distribution of Self Esteem Levels')
plt.xlabel('Self Esteem Level')
plt.ylabel('Frequency')
plt.legend()

plt.show()

# Analytically: 
data.groupby(data['self_esteem'] >= data['self_esteem'].mean()).size()
# Out:
# self_esteem
# False    507
# True     593
# dtype: int64

# %%
((data['depression'] > 10).sum() / len(data)) * 100
# Out:
# 56.36363636363636

# %%
plt.figure()
plt.pie([(data['depression'] > 10).mean() * 100, (1 - (data['depression'] > 10).mean()) * 100],
        labels=['Depression', 'No Depression'],
        colors=['orange', 'lightgreen'],
        autopct='%1.1f%%',
        startangle=90)
plt.title('Percentage of Students with Depression')
plt.show()

# %% [markdown]
# According to our own measurement of the definition "experiencing depression", 56.4% students have reported it.
#
# A new question appears. Are depression and self esteem related at all?

# %%
data['self_esteem'].corr(data['depression'])
# Out:
# -0.6996017571411518

# %% [markdown]
# ## ## Physiological Factors
#
# * **1) How many students experience headaches frequently?**

# %%
data['headache'].describe()
# Out:
# count    1100.000000
# mean        2.508182
# std         1.409356
# min         0.000000
# 25%         1.000000
# 50%         3.000000
# 75%         3.000000
# max         5.000000
# Name: headache, dtype: float64

# %%
data.groupby(data['headache'] >= 3).size()
# Out:
# headache
# False    544
# True     556
# dtype: int64

# %% [markdown]
# * **2) What is the average blood pressure reading among the students?**

# %%
data['blood_pressure'].value_counts()
# Out:
# 3    500
# 1    300
# 2    300
# Name: blood_pressure, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='blood_pressure', data=data, palette='viridis')
plt.title('Distribution of Blood Pressure Levels')
plt.xlabel('Blood Pressure Level')
plt.ylabel('Frequency')
plt.show()
print(f"Average blood pressure is {data['blood_pressure'].mean()}")
# Out:
# Average blood pressure is 2.1818181818181817

# %% [markdown]
# * **3) How many students rate their sleep quality as poor?**

# %%
data['sleep_quality'].value_counts()
# Out:
# 1    328
# 5    192
# 2    188
# 4    188
# 3    170
# 0     34
# Name: sleep_quality, dtype: int64

# %%
plt.figure()
sns.countplot(x='sleep_quality', data=data, palette='dark')
plt.title('Sleep quality distribution among students')
plt.ylabel('Number of Students')
plt.xlabel('Sleep quality value')
plt.show()

# %%
print(f"Number of students who reported low quality sleep: {(data['sleep_quality'] <= 2).sum()}")
# Out:
# Number of students who reported low quality sleep: 550

# %% [markdown]
# ## ## Enviromental Factors
#
# * **1) How many students live in conditions with high noise levels?**

# %%
data['noise_level'].describe()
# Out:
# count    1100.000000
# mean        2.649091
# std         1.328127
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max         5.000000
# Name: noise_level, dtype: float64

# %%
print(f"Number of students who reported high noise levels: {(data['noise_level']>=4).sum()}")
# Out:
# Number of students who reported high noise levels: 274

# %%
data_noise_level = data['noise_level']
data_noise_level = pd.cut(data_noise_level, bins = [0, 3, 5], labels = ['Low and mid noise', 'High noise'])
sns.barplot(x=data_noise_level.value_counts().index, y=data_noise_level.value_counts().values, palette = 'Set2')
plt.xlabel('Noise Level Category')
plt.ylabel('Number of Students')
plt.title('Number of Students by Noise Level Category')
plt.show()

# %% [markdown]
# **2) What percentage of students feel unsafe in their living conditions?**

# %%
data['safety'].describe()
# Out:
# count    1100.000000
# mean        2.737273
# std         1.406171
# min         0.000000
# 25%         2.000000
# 50%         2.000000
# 75%         4.000000
# max         5.000000
# Name: safety, dtype: float64

# %%
print(f"Number of students who feel unsafety: {(data['safety']<=1).sum()}")
data_safety = data['safety']
data_safety = pd.cut(data_safety, bins = [0, 1, 5], labels = ['Unsafe', 'Safe'])
sns.barplot(x=data_safety.value_counts().index, y=data_safety.value_counts().values, palette = 'Set3')
plt.xlabel('Safety level')
plt.ylabel('Number of Students')
plt.title('Number of Students by Safety values')
plt.show()
# Out:
# Number of students who feel unsafety: 217

# %%
safety_percentage = ((data['safety'] < 2).sum() / len(data)) * 100
print(f"Number of students who feel  unsafe: {safety_percentage}")
# Out:
# Number of students who feel  unsafe: 19.727272727272727

# %% [markdown]
#  **3) How many students have reported not having their basic needs met?**

# %%
print(f"Number of students with basic needs not met: {(data['basic_needs']<2).sum()}")
# Out:
# Number of students with basic needs not met: 213

# %% [markdown]
# ## # Enviromental Factors
#
# **1) How many students rate their academic performance as below average?**
#
# **2) What is the average study load reported by students?**
#
# **3) How many students have concerns about their future careers?**
# **

# %%
# 1
print(f"Number of students with academic performance below average: {(data['academic_performance'] <= data['academic_performance'].mean()).sum()}")

#2 
print (f"Study load average: {data['study_load'].mean()}")

#3
print (f"Students who have concerns about their future careers: {(data['future_career_concerns'] > 3).sum()}")
# Out:
# Number of students with academic performance below average: 561
# Study load average: 2.6218181818181816
# Students who have concerns about their future careers: 371

# %% [markdown]
# ## Social Factors
#
# **1) How many students feel they have strong social support?**
#
# **2) What percentage of students have experienced bullying?**
#
# **3) How many students participate in extracurricular activities?**

# %%
#1. This variable only takes values from 0 to 3. So "strong social support" will mean 3.
print (f"Students who feel a strong social support: {(data['social_support']>2).sum()}")

#2 
bullying_percentage = ((data['bullying'] > 3).sum() / len(data)) * 100
print(f"Number of students who suffered bullying: {bullying_percentage}")

#3 
print (f"Students participating in extracurricular activities: {(data['extracurricular_activities']>2).sum()}")
# Out:
# Students who feel a strong social support: 458
# Number of students who suffered bullying: 32.72727272727273
# Students participating in extracurricular activities: 550

# %% [markdown]
# ## ## Comparative analysis
#
# **1) Is there a correlation between anxiety level and academic performance?**

# %%
data['anxiety_level'].corr(data['academic_performance'])
# Out:
# -0.6496011296145088

# %% [markdown]
# **2) Do students with poor sleep quality also report higher levels of depression?**

# %%
data['sleep_quality'].corr(data['depression'])
# Out:
# -0.6931609071393334

# %% [markdown]
# Yes. As the correlation is negative, lower sleep quality value means a higher depression value.
#
# **3) Are students who experience bullying more likely to have a history of mental health issues?**

# %%
data['bullying'].corr(data['mental_health_history'])
# Out:
# 0.6243657971517642

# %% [markdown]
# ## General Exploration
#
# **1) Which factor (Psychological, Physiological, Environmental, Academic, Social) has the highest number of students reporting negative experiences or conditions?**

# %%
factors = {
    'Psychological': ['anxiety_level', 'self_esteem', 'mental_health_history', 'depression'],
    'Physiological': ['headache', 'blood_pressure', 'sleep_quality', 'breathing_problem'],
    'Environmental': ['noise_level', 'living_conditions', 'safety', 'basic_needs'],
    'Academic': ['academic_performance', 'study_load', 'teacher_student_relationship', 'future_career_concerns'],
    'Social': ['social_support', 'peer_pressure', 'extracurricular_activities', 'bullying']
}

factors_binary_dataframes = {}

# List of variables where higher values means negative experience
reverse_logic_columns = ['anxiety_level', 'mental_health_history', 'depression', 'headache', 'breathing_problem', 'noise_level', 'future_career_concerns', 'peer_pressure', 'bullying']

for factor, columns in factors.items(): 
    factor_data = pd.DataFrame()
    for column in columns:
        min_value, max_value = np.min(data[column]), np.max(data[column])
        
        if column in reverse_logic_columns:
            factor_data[column] = (data[column] < (min_value + max_value) / 2.0).astype(int)
        else:
            factor_data[column] = (data[column] > (min_value + max_value) / 2.0).astype(int)

    factors_binary_dataframes[factor] = factor_data

# %%
(factors_binary_dataframes['Psychological'].sum())
# Out:
# anxiety_level            512
# self_esteem              670
# mental_health_history    558
# depression               652
# dtype: int64

# %%
sum_of_negative_experiences = {}

for factor, binary_data in factors_binary_dataframes.items():
    feature_sum = binary_data.sum(axis=0)
    
    factor_sum = feature_sum.sum()
    
    sum_of_negative_experiences[factor] = {"Factor Total": factor_sum, "Feature Sums": feature_sum}

for factor, sums in sum_of_negative_experiences.items():
    print(f"Negative experiences for {factor}:\n")
    print(f"Factor Total: {sums['Factor Total']}")
    print("Feature Sums:")
    print(sums['Feature Sums'])
    print("\n")
# Out:
# Negative experiences for Psychological:
#
# Factor Total: 2392
# Feature Sums:
# anxiety_level            512
# self_esteem              670
# mental_health_history    558
# depression               652
# dtype: int64
#
#
# Negative experiences for Physiological:
#
# Factor Total: 2141
# Feature Sums:
# headache             544
# blood_pressure       500
# sleep_quality        550
# breathing_problem    547
# dtype: int64
#
#
# Negative experiences for Environmental:
#
# Factor Total: 2173
# Feature Sums:
# noise_level          537
# living_conditions    549
# safety               535
# basic_needs          552
# dtype: int64
#
#
# Negative experiences for Academic:
#
# Factor Total: 2155
# Feature Sums:
# academic_performance            539
# study_load                      545
# teacher_student_relationship    515
# future_career_concerns          556
# dtype: int64
#
#
# Negative experiences for Social:
#
# Factor Total: 2264
# Feature Sums:
# social_support                600
# ...

# %%
factors = {
    'Psychological': ['self_esteem', 'mental_health_history', 'depression'],
    'Physiological': ['headache', 'blood_pressure', 'sleep_quality', 'breathing_problem'],
    'Environmental': ['noise_level', 'living_conditions', 'safety', 'basic_needs'],
    'Academic': ['academic_performance', 'study_load', 'teacher_student_relationship', 'future_career_concerns'],
    'Social': ['social_support', 'peer_pressure', 'extracurricular_activities', 'bullying']
}

# factors is the same as before, with the exception of 'anxiety_level' deleted. 
from sklearn.ensemble import RandomForestRegressor

feature_importance_dict = {}
for factor, factor_features in factors.items():
    factor_data = data[factor_features]
    # model for each factor
    factor_model = RandomForestRegressor(random_state=1)
    factor_model.fit(factor_data, data['anxiety_level'])
    
    feature_importances = factor_model.feature_importances_
    
    feature_importance_dict[factor] = {'Feature': factor_features, 'Importance': feature_importances}

consolidated_importance_data = pd.concat({k: pd.DataFrame(v) for k, v in feature_importance_dict.items()})

plt.figure(figsize=(12, 8))
sns.barplot(x='Importance', y='Feature', hue='level_0', data=consolidated_importance_data.reset_index(), palette='Set1')
plt.title('Feature importance based on factor')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.legend(title='Factor', fontsize = 12)
plt.tight_layout()
plt.show()

features = [
    'self_esteem', 'mental_health_history', 'depression',
    'headache', 'blood_pressure', 'sleep_quality', 'breathing_problem',
    'noise_level', 'living_conditions', 'safety', 'basic_needs',
    'academic_performance', 'study_load', 'teacher_student_relationship', 'future_career_concerns',
    'social_support', 'peer_pressure', 'extracurricular_activities', 'bullying']

stress_model = RandomForestRegressor(random_state=1)
stress_model.fit(data[features], data['anxiety_level'])
feature_importances = stress_model.feature_importances_
importance_data = pd.DataFrame({'Feature': features, 'Importance': feature_importances})

plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=importance_data.sort_values(by='Importance', ascending=False), palette='Set2')
plt.title('Descending graphic showing the importance of each feature on anxiety_level')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Predicting the anxiety level

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor


X = data[features]
y = data['anxiety_level']
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 0)
stress_model = RandomForestRegressor(random_state = 1)
stress_model.fit(train_X, train_y)
val_predictions = stress_model.predict(val_X)
print (mean_absolute_error(val_y, val_predictions))
# Out:
# 2.581309090909091

# %% [markdown]
# But regression and feature importance from blood_pressure was low, maybe ignoring that column will make the model perform better?

# %%
features_to_ignore = ['blood_pressure']

X = data.drop(features_to_ignore, axis=1)
y = data['anxiety_level']
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 0)
stress_model = RandomForestRegressor(random_state = 1)
stress_model.fit(train_X, train_y)
val_predictions = stress_model.predict(val_X)
print (mean_absolute_error(val_y, val_predictions))
# Out:
# 0.0005454545454545339
